# %%
#this code is used to get figure 5.2

import networkx as nx
import operator
import pylab
import random
import sys

import time
import numpy as np
import osmnx as ox
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations
from IPython.display import clear_output
import matplotlib.cm as cm
import matplotlib.colors as colors
from IPython.display import Image
from pprint import pprint
import folium
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# network getting

# get 2021-04-01 bike networks(.graphml file and .png file) of Berlin


ox.utils.config(overpass_settings='[out:json][timeout:180][date:"2021-04-01T00:00:00Z"]')

place = 'Berlin, Germany'

cf1 = '["highway"~"cycleway"]["bicycle"!~"no"]'
cf2 = '["cycleway"]["cycleway"!~"no"]'
cf3 = '["cycleway:right"]["cycleway:right"!~"no"]'
cf4 = '["cycleway:left"]["cycleway:left"!~"no"]'
cf5 = '["cycleway:both"]["cycleway:both"!~"no"]'
cf6 = '["bicycle"~"designated"]'
cf7 = '["oneway:bicycle"]'




G_21_b1=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf1)
G_21_b2=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf2)
G_21_b3=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf3)
G_21_b4=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf4)
G_21_b5=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf5)
G_21_b6=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf6)
G_21_b7=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf7)

G_21_b11 = nx.compose(G_21_b1,  G_21_b2)
G_21_b12 = nx.compose(G_21_b11, G_21_b3)
G_21_b13 = nx.compose(G_21_b12, G_21_b4)
G_21_b14 = nx.compose(G_21_b13, G_21_b5)
G_21_b15 = nx.compose(G_21_b14, G_21_b6)
G_21_b16 = nx.compose(G_21_b15, G_21_b7)




G_21_b44=ox.simplification.consolidate_intersections(ox.project_graph(G_21_b16,to_crs='EPSG:3812'), tolerance=15, rebuild_graph=True, dead_ends=True, reconnect_edges=True)
G_21_b5=ox.project_graph(G_21_b44, to_crs='EPSG:4326')
fig, ax1_21 = ox.plot_graph(G_21_b5,node_size=0,bgcolor='black',edge_color='white',edge_linewidth=0.5)
print('Berlin 21_bike_net saved')

# %%
# network getting

# get 2020-01-01 bike networks(.graphml file and .png file) of Berlin


ox.utils.config(overpass_settings='[out:json][timeout:180][date:"2020-01-01T00:00:00Z"]')

place = 'Berlin, Germany'

cf1 = '["highway"~"cycleway"]["bicycle"!~"no"]'
cf2 = '["cycleway"]["cycleway"!~"no"]'
cf3 = '["cycleway:right"]["cycleway:right"!~"no"]'
cf4 = '["cycleway:left"]["cycleway:left"!~"no"]'
cf5 = '["cycleway:both"]["cycleway:both"!~"no"]'
cf6 = '["bicycle"~"designated"]'
cf7 = '["oneway:bicycle"]'



G_20_b1=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf1)
G_20_b2=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf2)
G_20_b3=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf3)
G_20_b4=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf4)
G_20_b5=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf5)
G_20_b6=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf6)
G_20_b7=ox.graph.graph_from_place(place, simplify=False, retain_all=True, 
                                  truncate_by_edge=True, which_result=None, buffer_dist=None, clean_periphery=True, 
                                  custom_filter = cf7)

G_20_b11 = nx.compose(G_20_b1,  G_20_b2)
G_20_b12 = nx.compose(G_20_b11, G_20_b3)
G_20_b13 = nx.compose(G_20_b12, G_20_b4)
G_20_b14 = nx.compose(G_20_b13, G_20_b5)
G_20_b15 = nx.compose(G_20_b14, G_20_b6)
G_20_b16 = nx.compose(G_20_b15, G_20_b7)


G_20_b44=ox.simplification.consolidate_intersections(ox.project_graph(G_20_b16,to_crs='EPSG:3812'), tolerance=15, rebuild_graph=True, dead_ends=True, reconnect_edges=True)
G_20_b5=ox.project_graph(G_20_b44, to_crs='EPSG:4326')
fig, ax1_20 = ox.plot_graph(G_20_b5,node_size=0,bgcolor='white',edge_color='black',edge_linewidth=0.5,save=True,filepath='data_indicator/Berlin/Berlin_b20.png',dpi=1080)
#ox.io.save_graphml(G_20_b5, filepath='data_indicator/Berlin/Berlin_20_bike.graphml', gephi=False, encoding='utf-8')
print('Berlin 20_bike_net saved')

# %%
print('--------------------------------------------part 1 start-----------------------------------------------------')

# %%
ox.utils.config(log_console=True, use_cache=True,overpass_settings='[out:json][timeout:180][date:"2020-01-01T00:00:00Z"]')



cf1 = '["highway"~"cycleway"]["bicycle"!~"no"]'
cf2 = '["cycleway"]["cycleway"!~"no"]'
cf3 = '["cycleway:right"]["cycleway:right"!~"no"]'
cf4 = '["cycleway:left"]["cycleway:left"!~"no"]'
cf5 = '["cycleway:both"]["cycleway:both"!~"no"]'
cf6 = '["bicycle"~"designated"]'
cf7 = '["oneway:bicycle"]'

center_point = (52.518, 13.3658)

G_20_1 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf1)
G_20_2 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf2)
G_20_3 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf3)
G_20_4 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf4)
G_20_5 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf5)
G_20_6 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf6)
G_20_7 = ox.graph.graph_from_point(center_point, dist=7000, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf7)

G_20_11 = nx.compose(G_20_1,  G_20_2)
G_20_12 = nx.compose(G_20_11, G_20_3)
G_20_13 = nx.compose(G_20_12, G_20_4)
G_20_14 = nx.compose(G_20_13, G_20_5)
G_20_15 = nx.compose(G_20_14, G_20_6)
G_20_16_1 = nx.compose(G_20_15, G_20_7)

# %%
print('--------------------------------------------part 1 end-----------------------------------------------------')

# %%
print('--------------------------------------------part 2 start-----------------------------------------------------')

# %%
ox.utils.config(log_console=True, use_cache=True,overpass_settings='[out:json][timeout:180][date:"2020-01-01T00:00:00Z"]')



cf1 = '["highway"~"cycleway"]["bicycle"!~"no"]'
cf2 = '["cycleway"]["cycleway"!~"no"]'
cf3 = '["cycleway:right"]["cycleway:right"!~"no"]'
cf4 = '["cycleway:left"]["cycleway:left"!~"no"]'
cf5 = '["cycleway:both"]["cycleway:both"!~"no"]'
cf6 = '["bicycle"~"designated"]'
cf7 = '["oneway:bicycle"]'

bbox1 = (52.4753,52.3674,13.7128,13.4873)

G_20_1 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf1)
G_20_2 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf2)
G_20_3 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf3)
G_20_4 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf4)
G_20_5 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf5)
G_20_6 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf6)
G_20_7 = ox.graph.graph_from_bbox(52.4753,52.3674,13.7128,13.4873,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf7)

G_20_11 = nx.compose(G_20_1,  G_20_2)
G_20_12 = nx.compose(G_20_11, G_20_3)
G_20_13 = nx.compose(G_20_12, G_20_4)
G_20_14 = nx.compose(G_20_13, G_20_5)
G_20_15 = nx.compose(G_20_14, G_20_6)
G_20_16_2 = nx.compose(G_20_15, G_20_7)

# %%
print('--------------------------------------------part 2 end-----------------------------------------------------')

# %%
print('--------------------------------------------part 3 start-----------------------------------------------------')

# %%
ox.utils.config(log_console=True, use_cache=True,overpass_settings='[out:json][timeout:180][date:"2020-01-01T00:00:00Z"]')



cf1 = '["highway"~"cycleway"]["bicycle"!~"no"]'
cf2 = '["cycleway"]["cycleway"!~"no"]'
cf3 = '["cycleway:right"]["cycleway:right"!~"no"]'
cf4 = '["cycleway:left"]["cycleway:left"!~"no"]'
cf5 = '["cycleway:both"]["cycleway:both"!~"no"]'
cf6 = '["bicycle"~"designated"]'
cf7 = '["oneway:bicycle"]'

center_point = (52.4396, 13.2354)

G_20_1 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf1)
G_20_2 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf2)
G_20_3 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf3)
G_20_4 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf4)
G_20_5 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf5)
G_20_6 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf6)
G_20_7 = ox.graph.graph_from_point(center_point, dist=4700, simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf7)

G_20_11 = nx.compose(G_20_1,  G_20_2)
G_20_12 = nx.compose(G_20_11, G_20_3)
G_20_13 = nx.compose(G_20_12, G_20_4)
G_20_14 = nx.compose(G_20_13, G_20_5)
G_20_15 = nx.compose(G_20_14, G_20_6)
G_20_16_3 = nx.compose(G_20_15, G_20_7)

# %%
print('--------------------------------------------part 3 end-----------------------------------------------------')

# %%
print('--------------------------------------------part 4 start-----------------------------------------------------')

# %%
ox.utils.config(log_console=True, use_cache=True,overpass_settings='[out:json][timeout:180][date:"2020-01-01T00:00:00Z"]')



cf1 = '["highway"~"cycleway"]["bicycle"!~"no"]'
cf2 = '["cycleway"]["cycleway"!~"no"]'
cf3 = '["cycleway:right"]["cycleway:right"!~"no"]'
cf4 = '["cycleway:left"]["cycleway:left"!~"no"]'
cf5 = '["cycleway:both"]["cycleway:both"!~"no"]'
cf6 = '["bicycle"~"designated"]'
cf7 = '["oneway:bicycle"]'

bbox1 = (52.6387,52.5595,13.5083,13.3673)

G_20_1 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf1)
G_20_2 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf2)
G_20_3 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf3)
G_20_4 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf4)
G_20_5 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf5)
G_20_6 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf6)
G_20_7 = ox.graph.graph_from_bbox(52.6387,52.5595,13.5083,13.3673,  simplify=False, retain_all=True, truncate_by_edge=False, clean_periphery=True, custom_filter=cf7)

G_20_11 = nx.compose(G_20_1,  G_20_2)
G_20_12 = nx.compose(G_20_11, G_20_3)
G_20_13 = nx.compose(G_20_12, G_20_4)
G_20_14 = nx.compose(G_20_13, G_20_5)
G_20_15 = nx.compose(G_20_14, G_20_6)
G_20_16_4 = nx.compose(G_20_15, G_20_7)

# %%
print('--------------------------------------------part 4 end-----------------------------------------------------')

# %%
# getting figure 5.3

G_20_b16.remove_edges_from(G_20_16_1.edges)
G_20_b16.remove_edges_from(G_20_16_2.edges)
G_20_b16.remove_edges_from(G_20_16_4.edges)


m = ox.plot_graph_folium(G_21_b16, weight=1, color='red',opacity=0.5)
m = ox.plot_graph_folium(G_20_b16,graph_map=m,weight=1.2,color='black')

m = ox.plot_graph_folium(G_20_16_1,graph_map=m,weight=1.2,color='blue')
m = ox.plot_graph_folium(G_20_16_2,graph_map=m,weight=1.2,color='yellow')
m = ox.plot_graph_folium(G_20_16_4,graph_map=m,weight=1.2,color='green')


m.save('data_indicator/Berlin/Berlin_parts.html')
